# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## Introduction

# %% [markdown]
# Another popular text analysis technique is called topic modeling. The ultimate goal of topic modeling is to find various topics that are present in your corpus. Each document in the corpus will be made up of at least one topic, if not multiple topics.
#
# In this notebook, we will be covering the steps on how to do **Latent Dirichlet Allocation (LDA)**, which is one of many topic modeling techniques. It was specifically designed for text data.
#
# To use a topic modeling technique, you need to provide (1) a document-term matrix and (2) the number of topics you would like the algorithm to pick up.
#
# Once the topic modeling technique is applied, your job as a human is to interpret the results and see if the mix of words in each topic make sense. If they don't make sense, you can try changing up the number of topics, the terms in the document-term matrix, model parameters, or even try a different model.

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# ## Topic Modeling - Attempt #1 (All Text)

# %%
# Let's read in our document-term matrix
import pandas as pd
import pickle

data = pd.read_pickle('dtm_stop.pkl')
data
# Out:
#                   abandon  abandoned  abena  ability  able  absolutely  abuse  \
# Leo                     0          0      0        1     1           0      1
# Silent Night            0          0      0        1     2           0      0
# The Color Purple        0          0      1        0     1           0      1
# The Family Man          1          2      0        0     0           1      0
# The Shepherd            0          1      0        0     0           0      0
#
#                   academicathalon  accept  accepts  ...  yous  youve  zane  \
# Leo                             2       1        0  ...     0      4     3
# Silent Night                    0       1        0  ...     0      0     0
# The Color Purple                0       1        1  ...     3      4     0
# The Family Man                  0       1        0  ...     0     13     0
# The Shepherd                    0       1        0  ...     0      4     0
#
#                   zanes  zaney  zip  zipping  zit  zone  zooming
# Leo                   1      1    3        2    1     0        0
# Silent Night          0      0    0        0    0     1        1
# The Color Purple      0      0    0        0    0     0        0
# The Family Man        0      0    0        0    0     0        0
# The Shepherd          0      0    0        0    0     0        0
#
# [5 rows x 4217 columns]

# %%
# Import the necessary modules for LDA with gensim
# Terminal / Anaconda Navigator: conda install -c conda-forge gensim
from gensim import matutils, models
import scipy.sparse

# import logging
# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# One of the required inputs is a term-document matrix
tdm = data.transpose()
tdm.head()
# Out:
#            Leo  Silent Night  The Color Purple  The Family Man  The Shepherd
# abandon      0             0                 0               1             0
# abandoned    0             0                 0               2             1
# abena        0             0                 1               0             0
# ability      1             1                 0               0             0
# able         1             2                 1               0             0

# %%
# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
cv = pickle.load(open("cv_stop.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator CountVectorizer from version 1.3.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term), we need to specify two other parameters - the number of topics and the number of passes. Let's start the number of topics at 2, see if the results make sense, and increase the number from there.

# %%
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term),
# we need to specify two other parameters as well - the number of topics and the number of passes
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.014*"comedydirectors" + 0.011*"offers" + 0.008*"iitztimmy" + 0.008*"gotcha" + 0.008*"lightin" + 0.008*"aircraft" + 0.008*"dont" + 0.007*"knocked" + 0.007*"jungle" + 0.007*"goddamn"'),
#  (1,
#   '0.014*"iitztimmy" + 0.014*"offers" + 0.011*"dont" + 0.010*"jungle" + 0.010*"knocked" + 0.009*"lightin" + 0.009*"yelping" + 0.008*"officer" + 0.007*"wrap" + 0.007*"hes"')]

# %%
# LDA for num_topics = 3
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.019*"municipal" + 0.017*"plant" + 0.011*"gods" + 0.009*"quiznos" + 0.008*"engine" + 0.008*"delta" + 0.008*"grunts" + 0.007*"gangbangers" + 0.007*"christmas" + 0.007*"scored"'),
#  (1,
#   '0.016*"comedydirectors" + 0.013*"offers" + 0.011*"aircraft" + 0.010*"gotcha" + 0.010*"iitztimmy" + 0.010*"lightin" + 0.010*"dont" + 0.009*"knocked" + 0.008*"goddamn" + 0.008*"hes"'),
#  (2,
#   '0.017*"iitztimmy" + 0.017*"offers" + 0.013*"dont" + 0.012*"jungle" + 0.012*"knocked" + 0.011*"lightin" + 0.011*"yelping" + 0.010*"officer" + 0.009*"wrap" + 0.009*"rhyme"')]

# %%
# LDA for num_topics = 4
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.017*"comedydirectors" + 0.013*"offers" + 0.011*"aircraft" + 0.010*"gotcha" + 0.010*"iitztimmy" + 0.010*"lightin" + 0.010*"dont" + 0.010*"knocked" + 0.009*"hes" + 0.009*"goddamn"'),
#  (1,
#   '0.018*"iitztimmy" + 0.017*"offers" + 0.013*"dont" + 0.013*"jungle" + 0.012*"knocked" + 0.012*"lightin" + 0.011*"yelping" + 0.010*"officer" + 0.010*"wrap" + 0.009*"rhyme"'),
#  (2,
#   '0.001*"iitztimmy" + 0.001*"offers" + 0.001*"dont" + 0.001*"jungle" + 0.001*"lightin" + 0.001*"knocked" + 0.001*"texting" + 0.000*"officer" + 0.000*"wrap" + 0.000*"comedydirectors"'),
#  (3,
#   '0.021*"municipal" + 0.018*"plant" + 0.012*"gods" + 0.010*"quiznos" + 0.009*"engine" + 0.008*"grunts" + 0.008*"delta" + 0.008*"gangbangers" + 0.008*"christmas" + 0.007*"scored"')]

# %% [markdown]
# These topics aren't looking too great. We've tried modifying our parameters. Let's try modifying our terms list as well.

# %% [markdown]
# ## Topic Modeling - Attempt #2 (Nouns Only)

# %% [markdown]
# One popular trick is to look only at terms that are from one part of speech (only nouns, only adjectives, etc.). Check out the UPenn tag set: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html.

# %%
# Let's create a function to pull out nouns from a string of text
from nltk import word_tokenize, pos_tag

def nouns(text):
    '''Given a string of text, tokenize the text and pull out only the nouns.'''
    is_noun = lambda pos: pos[:2] == 'NN'
    tokenized = word_tokenize(text)
    all_nouns = [word for (word, pos) in pos_tag(tokenized) if is_noun(pos)]
    return ' '.join(all_nouns)

# %%
# Read in the cleaned data, before the CountVectorizer step
data_clean = pd.read_pickle('data_clean.pkl')
data_clean
# Out:
#                                                          transcript
# Leo               title leorelease date november  genre animated...
# Silent Night      silent night  director john woowriter robert a...
# The Color Purple  director blitz bazawulewriters marcus gardley ...
# The Family Man    title the family planrelease date december  ru...
# The Shepherd      the shepherd is a  british drama short film wr...

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns = pd.DataFrame(data_clean.transcript.apply(nouns))
data_nouns
# Out:
#                                                          transcript
# Leo               title leorelease date november genre comedydir...
# Silent Night      night director john woowriter joel kinnaman to...
# The Color Purple  director blitz bazawulewriters alice walker ma...
# The Family Man    family planrelease date december hour minutesg...
# The Shepherd      shepherd drama film iain softley ben radcliffe...

# %%
# Create a new document-term matrix using only nouns
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Re-add the additional stop words since we are recreating the document-term matrix
add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people','youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said']
a_stop_words = list(text.ENGLISH_STOP_WORDS.union(add_stop_words))

# Recreate a document-term matrix with only nouns
cvn = CountVectorizer(stop_words=a_stop_words)
data_cvn = cvn.fit_transform(data_nouns.transcript)
data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.vocabulary_)
data_dtmn.index = data_nouns.index
data_dtmn
# Out:
#                   title  leorelease  date  november  genre  comedydirectors  \
# Leo                   1           0     1         1      0                1
# Silent Night          1           0     0         1      0                0
# The Color Purple      0           1     0         1      0                3
# The Family Man        0           0     0         1      1                1
# The Shepherd          0           0     0         1      0                0
#
#                   marianetti  robert  smigel  david  ...  pathfinders  batman  \
# Leo                        0       0       0      0  ...            0       8
# Silent Night               2       0       0      0  ...            0       0
# The Color Purple           0       0       3      3  ...            1       0
# The Family Man             2       1       0      0  ...            1       1
# The Shepherd               1       0       0      0  ...            0       1
#
#                   johnny  marker  flares  patrol  skipper  enemy  fighter  \
# Leo                    2       3       1       2        1      1        0
# Silent Night           0       0       0       0        0      0        1
# The Color Purple       1       0       0       0        0      0        0
# The Family Man         3       0       0       0        0      0        0
# The Shepherd           3       0       0       0        0      0        0
#
#                   carol
# Leo                   0
# Silent Night          1
# The Color Purple      0
# The Family Man        0
# The Shepherd          0
#
# [5 rows x 2442 columns]

# %%
# Create the gensim corpus
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))

# Create the vocabulary dictionary
id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
# Let's start with 2 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.013*"music" + 0.009*"kids" + 0.007*"hey" + 0.007*"hes" + 0.007*"man" + 0.006*"playing" + 0.006*"god" + 0.006*"year" + 0.006*"engine" + 0.006*"radio"'),
#  (1,
#   '0.011*"celie" + 0.011*"gon" + 0.010*"god" + 0.009*"man" + 0.008*"hell" + 0.007*"hey" + 0.006*"baby" + 0.006*"aint" + 0.006*"lord" + 0.006*"woman"')]

# %%
# Let's try topics = 3
ldan = models.LdaModel(corpus=corpusn, num_topics=3, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.013*"kids" + 0.010*"hey" + 0.010*"hes" + 0.008*"god" + 0.008*"gon" + 0.008*"year" + 0.007*"life" + 0.007*"mom" + 0.007*"look" + 0.007*"family"'),
#  (1,
#   '0.019*"delta" + 0.015*"music" + 0.015*"charlie" + 0.011*"radio" + 0.011*"christmas" + 0.010*"playing" + 0.007*"freddie" + 0.006*"failure" + 0.006*"home" + 0.005*"fuel"'),
#  (2,
#   '0.019*"music" + 0.013*"man" + 0.010*"godlock" + 0.010*"engine" + 0.009*"celie" + 0.009*"god" + 0.009*"gon" + 0.008*"grunts" + 0.008*"woman" + 0.007*"playing"')]

# %%
# Let's try 4 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.042*"music" + 0.023*"godlock" + 0.022*"engine" + 0.019*"grunts" + 0.016*"playing" + 0.016*"tires" + 0.015*"member" + 0.015*"officer" + 0.014*"radio" + 0.013*"groans"'),
#  (1,
#   '0.016*"kids" + 0.014*"year" + 0.011*"class" + 0.009*"leo" + 0.008*"hes" + 0.008*"kid" + 0.007*"school" + 0.006*"life" + 0.006*"lot" + 0.006*"hey"'),
#  (2,
#   '0.014*"celie" + 0.013*"god" + 0.013*"gon" + 0.011*"man" + 0.010*"hell" + 0.008*"hey" + 0.007*"baby" + 0.007*"lord" + 0.007*"aint" + 0.007*"woman"'),
#  (3,
#   '0.010*"hey" + 0.009*"god" + 0.009*"delta" + 0.008*"hes" + 0.008*"family" + 0.008*"gon" + 0.007*"oh" + 0.007*"dan" + 0.007*"mom" + 0.007*"guy"')]

# %% [markdown]
# ## Topic Modeling - Attempt #3 (Nouns and Adjectives)

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)]
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean.transcript.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                          transcript
# Leo               title leorelease date november genre comedydir...
# Silent Night      silent night director john woowriter joel kinn...
# The Color Purple  director blitz bazawulewriters gardley alice w...
# The Family Man    family planrelease date december runtime hour ...
# The Shepherd      shepherd british drama short film iain softley...

# %%
# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=a_stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adj.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.vocabulary_)
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#                   title  leorelease  date  november  genre  comedydirectors  \
# Leo                   1           1     0         2      0                1
# Silent Night          1           2     0         0      0                0
# The Color Purple      0           1     1         0      0                4
# The Family Man        0           0     0         0      1                1
# The Shepherd          0           0     0         0      0                0
#
#                   marianetti  robert  smigel  david  ...  marker  flares  \
# Leo                        0       0       0      2  ...       0       0
# Silent Night               2       0       1      0  ...       0       0
# The Color Purple           0       0       1      5  ...       1       2
# The Family Man             2       1       1      0  ...       0       0
# The Shepherd               1       0       1      0  ...       0       0
#
#                   crippled  dense  patrol  skipper  flank  enemy  fighter  \
# Leo                      3      3       1        2      1      1        0
# Silent Night             0      0       0        0      0      0        1
# The Color Purple         2      0       0        0      0      0        0
# The Family Man           4      0       0        0      0      0        0
# The Shepherd             4      0       0        0      0      0        0
#
#                   carol
# Leo                   0
# Silent Night          1
# The Color Purple      0
# The Family Man        0
# The Shepherd          0
#
# [5 rows x 2999 columns]

# %%
# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

# Create the vocabulary dictionary
id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
# Let's start with 2 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.015*"music" + 0.007*"radio" + 0.007*"kids" + 0.007*"godlock" + 0.007*"playing" + 0.006*"year" + 0.006*"engine" + 0.006*"delta" + 0.006*"grunts" + 0.005*"good"'),
#  (1,
#   '0.013*"god" + 0.013*"oh" + 0.012*"hey" + 0.010*"good" + 0.009*"gon" + 0.007*"man" + 0.006*"celie" + 0.006*"shug" + 0.005*"mmm" + 0.005*"hell"')]

# %%
# Let's try 3 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.012*"kids" + 0.010*"year" + 0.008*"class" + 0.007*"oh" + 0.007*"great" + 0.007*"uh" + 0.006*"good" + 0.006*"hes" + 0.006*"kid" + 0.005*"hey"'),
#  (1,
#   '0.014*"oh" + 0.013*"hey" + 0.012*"god" + 0.010*"good" + 0.009*"dad" + 0.008*"dan" + 0.008*"hes" + 0.008*"sorry" + 0.007*"family" + 0.007*"mom"'),
#  (2,
#   '0.017*"music" + 0.009*"man" + 0.008*"radio" + 0.008*"god" + 0.008*"good" + 0.007*"godlock" + 0.007*"playing" + 0.007*"celie" + 0.007*"engine" + 0.007*"shug"')]

# %%
# Let's try 4 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.013*"kids" + 0.011*"year" + 0.009*"class" + 0.008*"oh" + 0.008*"great" + 0.007*"uh" + 0.007*"good" + 0.006*"hes" + 0.006*"kid" + 0.006*"hey"'),
#  (1,
#   '0.013*"god" + 0.012*"celie" + 0.011*"shug" + 0.010*"good" + 0.010*"oh" + 0.010*"hey" + 0.010*"gon" + 0.009*"man" + 0.008*"hell" + 0.007*"aint"'),
#  (2,
#   '0.015*"oh" + 0.014*"hey" + 0.013*"god" + 0.010*"good" + 0.010*"dad" + 0.009*"dan" + 0.008*"hes" + 0.008*"sorry" + 0.008*"family" + 0.007*"mom"'),
#  (3,
#   '0.034*"music" + 0.016*"radio" + 0.015*"playing" + 0.015*"godlock" + 0.014*"engine" + 0.013*"delta" + 0.013*"grunts" + 0.010*"christmas" + 0.010*"officer" + 0.010*"tires"')]

# %% [markdown]
# ## Identify Topics in Each Document

# %% [markdown]
# Out of the 9 topic models we looked at, the nouns and adjectives, 4 topic one made the most sense. So let's pull that down here and run it through some more iterations to get more fine-tuned topics.

# %%
# Our final LDA model (for now)
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.011*"oh" + 0.010*"hey" + 0.010*"god" + 0.009*"good" + 0.008*"music" + 0.008*"man" + 0.007*"gon" + 0.007*"kids" + 0.006*"uh" + 0.005*"hes"'),
#  (1,
#   '0.024*"delta" + 0.017*"charlie" + 0.014*"music" + 0.013*"freddie" + 0.011*"christmas" + 0.010*"radio" + 0.010*"playing" + 0.007*"lima" + 0.006*"sir" + 0.006*"good"'),
#  (2,
#   '0.000*"music" + 0.000*"honks" + 0.000*"multiple" + 0.000*"targets" + 0.000*"stereo" + 0.000*"sight" + 0.000*"route" + 0.000*"upbeat" + 0.000*"confirm" + 0.000*"sighs"'),
#  (3,
#   '0.000*"upbeat" + 0.000*"stereo" + 0.000*"multiple" + 0.000*"targets" + 0.000*"route" + 0.000*"confirm" + 0.000*"honks" + 0.000*"sight" + 0.000*"ominous" + 0.000*"male"')]

# %% [markdown]
# These four topics look pretty decent. Let's settle on these for now.
# * Topic 0: profanity
# * Topic 1: guns
# * Topic 2: dogs,tweet
# * Topic 3: mom, parents

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(0, 'Leo'),
#  (0, 'Silent Night'),
#  (0, 'The Color Purple'),
#  (0, 'The Family Man'),
#  (1, 'The Shepherd')]

# %% [markdown]
# For a first pass of LDA, these kind of make sense to me, so we'll call it a day for now.
# * Topic 0: profanity[Bill,Kevin,Mike]
# * Topic 1: guns[Anthony,Jim,Joe,John]
# * Topic 2: dogs,tweet[Gabriel,Dave,Ricky]
# * Topic 3: mom, parents[Ali,Louis,Hasan]

# %% [markdown]
# ### Assignment:
# 1. Try further modifying the parameters of the topic models above and see if you can get better topics.
# 2. Create a new topic model that includes terms from a different [part of speech](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html) and see if you can get better topics.

# %% [markdown]
# ### Assignment Solutions
# 1. Try further modifying the parameters of the topic models above and see if you can get better topics.

# %%
lda_model = models.LdaModel(corpus=corpusna, id2word=id2wordna, num_topics=5, passes=100, alpha=0.5, eta=0.01)

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.000*"oh" + 0.000*"hey" + 0.000*"music" + 0.000*"good" + 0.000*"kids" + 0.000*"god" + 0.000*"uh" + 0.000*"man" + 0.000*"look" + 0.000*"gon"'),
#  (1,
#   '0.013*"god" + 0.013*"good" + 0.012*"celie" + 0.011*"shug" + 0.011*"oh" + 0.010*"delta" + 0.010*"gon" + 0.010*"hey" + 0.008*"man" + 0.008*"hell"'),
#  (2,
#   '0.019*"oh" + 0.018*"hey" + 0.016*"god" + 0.013*"good" + 0.013*"dad" + 0.011*"dan" + 0.010*"sorry" + 0.010*"hes" + 0.010*"family" + 0.009*"mom"'),
#  (3,
#   '0.000*"music" + 0.000*"hey" + 0.000*"good" + 0.000*"oh" + 0.000*"man" + 0.000*"god" + 0.000*"radio" + 0.000*"kids" + 0.000*"playing" + 0.000*"godlock"'),
#  (4,
#   '0.019*"music" + 0.011*"kids" + 0.011*"godlock" + 0.010*"year" + 0.010*"engine" + 0.008*"grunts" + 0.008*"radio" + 0.008*"class" + 0.007*"gang" + 0.007*"playing"')]

# %% [markdown]
# These four topics look pretty decent. Let's settle on these for now.
# * Topic 0: wife,mom
# * Topic 1: profanity
# * Topic 2: gun,kid,religion
# * Topic 3: dogs,mexican
# * Topic 4: parents,brown

# %%
corpus_transformed = lda_model[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(4, 'Leo'),
#  (4, 'Silent Night'),
#  (1, 'The Color Purple'),
#  (2, 'The Family Man'),
#  (1, 'The Shepherd')]

# %% [markdown]
# * Topic 0: wife,mom [Anthony,Dave,Joe,John,Kevin]
# * Topic 1: profanity [Jim,Ricky]
# * Topic 2: gun,kid,religion [Bill]
# * Topic 3: dogs,mexican [Gabriel,Mike]
# * Topic 4: parents,brown [Ali,Hasan,Louis]

# %% [markdown]
# 2. Create a new topic model that includes terms from a different [part of speech](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html) and see if you can get better topics.

# %% [markdown]
# * * ##### Topic Modeling - Attempt #4 (Nouns,Adjectives,Verbs and no proper nouns)
# * ##### [reference](https://sites.google.com/site/partofspeechhelp/home)

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj_verb(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj_verb = lambda pos: (pos[:2] == 'NN' or pos[:2] == 'JJ' or pos[:2] == 'VB') and pos[:2] != 'NNP'
    tokenized = word_tokenize(text)
    nouns_adj_verb = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj_verb(pos)]
    return ' '.join(nouns_adj_verb)

# %%
data_nouns_adj_verb = pd.DataFrame(data_clean.transcript.apply(nouns_adj_verb))
data_nouns_adj_verb
# Out:
#                                                          transcript
# Leo               title leorelease date november genre animated ...
# Silent Night      silent night director john woowriter robert ly...
# The Color Purple  director blitz bazawulewriters marcus gardley ...
# The Family Man    title family planrelease date december runtime...
# The Shepherd      shepherd is british drama short film written d...

# %%
cvnav = CountVectorizer(stop_words=a_stop_words, max_df=.8)
data_cvnav = cvnav.fit_transform(data_nouns_adj_verb.transcript)
data_dtmnav = pd.DataFrame(data_cvnav.toarray(), columns=cvnav.vocabulary_)
data_dtmnav.index = data_nouns_adj_verb.index
data_dtmnav
# Out:
#                   title  leorelease  date  november  genre  animated  \
# Leo                   0           0     1         1      1         2
# Silent Night          0           0     1         2      0         0
# The Color Purple      0           0     0         1      1         0
# The Family Man        1           2     0         0      0         0
# The Shepherd          0           1     0         0      0         0
#
#                   comedydirectors  robert  marianetti  smigel  ...  dense  \
# Leo                             0       0           1       0  ...      0
# Silent Night                    0       0           0       0  ...      0
# The Color Purple                1       0           5       0  ...      3
# The Family Man                  0       1           1       2  ...      0
# The Shepherd                    0       0           0       0  ...      0
#
#                   patrol  vanished  led  skipper  flank  pursuing  enemy  \
# Leo                    3         3    1        1      3         2      1
# Silent Night           0         0    0        0      0         0      0
# The Color Purple       3         0    0        0      0         0      0
# The Family Man         8         0    0        0      0         0      0
# The Shepherd           4         0    0        0      0         0      0
#
#                   fighter  vocalizing
# Leo                     0           0
# Silent Night            1           1
# The Color Purple        0           0
# The Family Man          0           0
# The Shepherd            0           0
#
# [5 rows x 3964 columns]

# %%
corpusnav = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmnav.transpose()))

# Create the vocabulary dictionary
id2wordnav = dict((v, k) for k, v in cvnav.vocabulary_.items())

# %%
lda_nav = models.LdaModel(corpus=corpusnav, id2word=id2wordnav, num_topics=5, passes=100, alpha=0.5, eta=0.01)

# %%
lda_nav.print_topics()
# Out:
# [(0,
#   '0.018*"oh" + 0.012*"come" + 0.012*"god" + 0.012*"dad" + 0.012*"gon" + 0.011*"look" + 0.009*"dan" + 0.009*"hes" + 0.009*"good" + 0.008*"sorry"'),
#  (1,
#   '0.033*"delta" + 0.027*"charlie" + 0.021*"freddie" + 0.020*"christmas" + 0.019*"music" + 0.018*"playing" + 0.015*"come" + 0.014*"radio" + 0.013*"celle" + 0.012*"sir"'),
#  (2,
#   '0.017*"come" + 0.013*"gon" + 0.010*"oh" + 0.010*"say" + 0.009*"god" + 0.008*"aint" + 0.008*"good" + 0.007*"celie" + 0.007*"kids" + 0.007*"ill"'),
#  (3,
#   '0.038*"music" + 0.032*"playing" + 0.028*"godlock" + 0.020*"engine" + 0.019*"gang" + 0.017*"grunts" + 0.017*"screeching" + 0.017*"tires" + 0.016*"radio" + 0.014*"groans"'),
#  (4,
#   '0.011*"pen" + 0.011*"ability" + 0.011*"drill" + 0.011*"trigger" + 0.011*"alarm" + 0.011*"mike" + 0.011*"valentines" + 0.011*"pic" + 0.011*"white" + 0.011*"scam"')]

# %% [markdown]
# * Topic 0: dogs,friend,mexican
# * Topic 1: profanity
# * Topic 2: gun,kid
# * Topic 3: mom,parents,gay
# * Topic 4: wife,kid,mom

# %% [markdown]
# #### * [reference](https://towardsdatascience.com/latent-dirichlet-allocation-lda-a-guide-to-probabilistic-modeling-approach-for-topic-discovery-8cb97c08da3c)
